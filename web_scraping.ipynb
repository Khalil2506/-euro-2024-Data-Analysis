# %%
import LanusStats as ls
import pandas as pd 

fbref = ls.Fbref()
fotmo = ls.FotMob()
score = ls.ThreeSixFiveScores()

# %%
ls.get_available_pages()
# Out:
# dict_keys(['Fbref', 'Sofascore', '365Scores', 'Fotmob', 'Transfermarkt'])

# %%
ls.get_available_leagues('Fbref')
# Out:
# ['Copa de la Liga',
#  'Primera Division Argentina',
#  'Primera Division Uruguay',
#  'Brasileirao',
#  'Brasileirao B',
#  'Primera Division Colombia',
#  'Primera Division Chile',
#  'Primera Division Peru',
#  'Primera Division Venezuela',
#  'Primera Division Ecuador',
#  'Primera Division Bolivia',
#  'Primera Division Paraguay',
#  'Brasileirao F',
#  'MLS',
#  'USL Championship',
#  'Premier League',
#  'La Liga',
#  'Ligue 1',
#  'Bundesliga',
#  'Serie A',
#  'Big 5 European Leagues',
#  'Danish Superliga',
#  'Eredivise',
#  'Primeira Liga Portugal',
#  'Copa America',
#  'Euros',
#  'Saudi League',
#  'EFL Championship',
#  'La Liga 2',
#  'Belgian Pro League',
#  'Challenger Pro League',
#  '2. Bundesliga',
#  'Ligue 2',
#  'Serie B',
#  'J1 League',
#  'NSWL',
#  'Wowens Super League',
#  'Liga F',
#  'Premier Division South Africa',
#  'Champions League',
#  'Europa League',
#  'Conference League',
#  'Copa Libertadores']

# %%
ls.get_available_season_for_leagues('Fbref','Copa America')
# Out:
# {'id': 685, 'slug': 'Copa-America', 'season': {'2019', '2021', '2024'}}

# %%
fbref = ls.Fbref()
fbref.get_player_season_stats('stats','Copa America','2024')
#df_player = pd.DataFrame(datos_player)
#df_player.to_excel('player_euro_2024.xlsx')
# Out:
# Starting to scrape player data from Fbref...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 fbref = ls.Fbref()
# ----> 2 fbref.get_player_season_stats('stats','Copa America','2024')
#       3 #df_player = pd.DataFrame(datos_player)
#       4 #df_player.to_excel('player_euro_2024.xlsx')
#
# File c:\Users\thermaltaque\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\fbref.py:171, in Fbref.get_player_season_stats(self, stat, league, season, save_csv, add_page_name)
#     168 print("Starting to scrape player data from Fbref...")
#     169 possible_stats_exception(self.possible_stats, stat)
# --> 171 leagues = get_possible_leagues_for_page(league, season, 'Fbref')
#     173 today = datetime.now().strftime('%Y-%m-%d')
#     175 if league == 'Big 5 European Leagues':
#
# File c:\Users\thermaltaque\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\functions.py:700, in get_possible_leagues_for_page(league, season, page)
#     689 def get_possible_leagues_for_page(league, season, page):
#     690     """Get possible leagues for a particular page
#     691
#     692     Args:
#    (...)
#     698         dict: leagues that are possible for that page.
#     699     """
# --> 700     leagues = get_possible_leagues(league, season, page)[page]
#     701     return leagues
#
# File c:\Users\thermaltaque\AppData\Local\Programs\Python\Python310\lib\site-packages\LanusStats\functions.py:683, in get_possible_leagues(league, season, page)
#     681     raise InvalidLeagueException('league', possible_leagues_list)
#     682 if page not in ['Transfermarkt']:
# --> 683     possible_seasons_list = list(possible_leagues[page][league]['seasons'])
#     684     if season != None and season not in possible_seasons_list:
#     685         raise InvalidSeasonException('league', possible_seasons_list)
#
# KeyError: 'seasons'

# %%
fotmo.get_players_stats_season('Euros','2024',"rating")
# Out:
# Possible values for stat parameter: ['goals', 'goal_assist', '_goals_and_goal_assist', 'rating', 'goals_per_90', 'expected_goals', 'expected_goals_per_90', 'expected_goalsontarget', 'ontarget_scoring_att', 'total_scoring_att', 'accurate_pass', 'big_chance_created', 'total_att_assist', 'accurate_long_balls', 'expected_assists', 'expected_assists_per_90', '_expected_goals_and_expected_assists_per_90', 'won_contest', 'big_chance_missed', 'penalty_won', 'won_tackle', 'interception', 'effective_clearance', 'outfielder_block', 'penalty_conceded', 'poss_won_att_3rd', 'clean_sheet', '_save_percentage', 'saves', '_goals_prevented', 'goals_conceded', 'fouls', 'yellow_card', 'red_card']
#           id  teamId             name  \
# 0     605654    6720      Fabián Ruiz
# 1     614834    6720        Dani Olmo
# 2      95078    8570       Toni Kroos
# 3     460632    8570   Joshua Kimmich
# 4    1061249    8361          Vitinha
# ..       ...     ...              ...
# 300   700070    8565      Martin Adam
# 301   599353    8498        Che Adams
# 302   737857    8205   Dusan Vlahovic
# 303  1225995    8496     Robin Hranac
# 304   668422    8498  Anthony Ralston
#
#                                          substatValue  \
# 0    {'value': 2, 'format': 'number', 'fractions': 0}
# 1    {'value': 3, 'format': 'number', 'fractions': 0}
# 2    {'value': 1, 'format': 'number', 'fractions': 0}
# 3    {'value': 0, 'format': 'number', 'fractions': 0}
# 4    {'value': 1, 'format': 'number', 'fractions': 0}
# ..                                                ...
# 300  {'value': 0, 'format': 'number', 'fractions': 0}
# 301  {'value': 0, 'format': 'number', 'fractions': 0}
# 302  {'value': 0, 'format': 'number', 'fractions': 0}
# 303  {'value': 0, 'format': 'number', 'fractions': 0}
# 304  {'value': 0, 'format': 'number', 'fractions': 0}
#
#                                              statValue  rank     type    name  \
# 0    {'name': 'rating', 'value': 8.04, 'format': 'f...     1  players  rating
# 1    {'name': 'rating', 'value': 7.92, 'format': 'f...     2  players  rating
# 2    {'name': 'rating', 'value': 7.86, 'format': 'f...     3  players  rating
# 3    {'name': 'rating', 'value': 7.82, 'format': 'f...     4  players  rating
# 4    {'name': 'rating', 'value': 7.76, 'format': 'f...     5  players  rating
# ..                                                 ...   ...      ...     ...
# 300  {'name': 'rating', 'value': 6, 'format': 'frac...   301  players  rating
# 301  {'name': 'rating', 'value': 5.95, 'format': 'f...   302  players  rating
# 302  {'name': 'rating', 'value': 5.86, 'format': 'f...   303  players  rating
# 303  {'name': 'rating', 'value': 5.83, 'format': 'f...   304  players  rating
# 304  {'name': 'rating', 'value': 5.79, 'format': 'f...   305  players  rating
#
#      value    format  fractions
# 0     8.04  fraction          2
# 1     7.92  fraction          2
# 2     7.86  fraction          2
# 3     7.82  fraction          2
# 4     7.76  fraction          2
# ..     ...       ...        ...
# 300   6.00  fraction          2
# 301   5.95  fraction          2
# 302   5.86  fraction          2
# 303   5.83  fraction          2
# 304   5.79  fraction          2
#
# [305 rows x 11 columns]
